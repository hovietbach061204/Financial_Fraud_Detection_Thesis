# %%
import pandas as pd
df = pd.read_csv('/Volumes/SandiskSSD/Developer/AI_Document/Financial_Fraud_Detection_Thesis/data/merchants.csv')

# %%
df
# Out:
#                                    category|merchant_name
# gas_transport|fraud_Tillman         Dickinson and Labadie
# gas_transport|fraud_Kuvalis Ltd                       NaN
# gas_transport|fraud_Robel          Cummerata and Prosacco
# gas_transport|fraud_Bernhard Inc                      NaN
# gas_transport|fraud_Kling Inc                         NaN
# ...                                                   ...
# travel|fraud_Hackett Group                            NaN
# travel|fraud_Block-Hauck                              NaN
# travel|fraud_Kessler Inc                              NaN
# travel|fraud_Goyette-Herzog                           NaN
# travel|fraud_Douglas                 DuBuque and McKenzie
#
# [800 rows x 1 columns]
